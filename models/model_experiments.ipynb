# %%
import pickle
import sqlite3
import sys
from datetime import datetime as dt

import numpy as np
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    make_scorer,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline
from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, Real
from sqlalchemy import create_engine

# %%
def load_data(database_filepath):
    engine = create_engine(f"sqlite:///{database_filepath}")
    df = pd.read_sql("messages", engine)
    X = df['message']
    y = df.drop(columns=["message", "id", "original", "genre"])
    infrequent_labels = y.sum()[y.sum()<10].index.tolist()
    y.drop(columns=infrequent_labels, inplace = True)
    y[y>1]=1
    return (X, y, y.columns)


def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens


def build_model():
    model = Pipeline(
        [
            (
                "tf-idf vectorization",
                TfidfVectorizer(tokenizer=tokenize, ngram_range=(1, 2)),
            ),
            (
                "classifier",
                MultiOutputClassifier(
                    estimator=RandomForestClassifier(
                        class_weight="balanced", n_estimators=200, max_depth=5,
                    )
                ),
            ),
        ],
        verbose=True,
    )
    return model


def evaluate_model(model, X, y):

    predictions = model.predict(X)
    predictions = pd.DataFrame(predictions, columns=y.columns)

    reports = []
    for label in list(y):
        ylab = y[label]
        predlab = predictions[label]
        rep = dict()
        rep["category"] = label
        rep["accuracy"] = accuracy_score(ylab, predlab)
        print(rep)

        # Confusion matrix:
        conf = pd.Series(
            confusion_matrix(ylab, predlab).ravel(), index=["tn", "fp", "fn", "tp"]
        )
        conf_dict = {ind: conf[ind] for ind in conf.index}
        rep.update(conf_dict)
        reports.append(pd.Series(rep))
        print(pd.Series(rep))

    df_report = np.round(pd.DataFrame(reports).set_index("category"), 2)
    return df_report


def save_model(model, model_filepath):
    """Perform pickle dump of the model"""

    pickle.dump(model, open(model_filepath, "wb"))

# %%
X, y, columns = load_data('../data/DisasterResponse.db')

# %%
model = build_model()

# %%
model.fit(X, y)
# Out:
# [Pipeline]  (step 1 of 2) Processing tf-idf vectorization, total=   8.3s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=  43.9s
# Pipeline(steps=[('tf-idf vectorization',
#                  TfidfVectorizer(ngram_range=(1, 2),
#                                  tokenizer=<function tokenize at 0x7fc25bfb6af0>)),
#                 ('classifier',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(class_weight='balanced',
#                                                                         max_depth=5,
#                                                                         n_estimators=200)))],
#          verbose=True)

# %%
report = evaluate_model(model, X, y)
# Out:
# {'category': 'related', 'accuracy': 0.7541959108941104}
# category     related
# accuracy    0.754196
# tn              4420
# fp              1702
# fn              4742
# tp             15352
# dtype: object
# {'category': 'request', 'accuracy': 0.8765639304241685}
# category     request
# accuracy    0.876564
# tn             19790
# fp              1952
# fn              1284
# tp              3190
# dtype: object
# {'category': 'offer', 'accuracy': 0.996910283796155}
# category      offer
# accuracy    0.99691
# tn            26066
# fp               32
# fn               49
# tp               69
# dtype: object
# {'category': 'aid_related', 'accuracy': 0.7711702776930119}
# category    aid_related
# accuracy        0.77117
# tn                13168
# fp                 2188
# fn                 3811
# tp                 7049
# dtype: object
# {'category': 'medical_help', 'accuracy': 0.8453234665852914}
# category    medical_help
# accuracy        0.845323
# tn                 20844
# fp                  3288
# fn                   767
# tp                  1317
# dtype: object
# {'category': 'medical_products', 'accuracy': 0.9129157766249618}
# category    medical_products
# accuracy            0.912916
# tn                     23101
# fp                      1802
# fn                       481
# tp                       832
# dtype: object
# {'category': 'search_and_rescue', 'accuracy': 0.9416005492828807}
# category    search_and_rescue
# accuracy             0.941601
# tn                      24301
# fp                       1191
# fn                        340
# tp                        384
# dtype: object
# {'category': 'security', 'accuracy': 0.977113213304852}
# category    security
# accuracy    0.977113
# tn             25419
# fp               326
# fn               274
# tp               197
# dtype: object
# {'category': 'military', 'accuracy': 0.8595895636252671}
# category    military
# accuracy     0.85959
# tn             21869
# fp              3487
# fn               194
# tp               666
# dtype: object
# {'category': 'water', 'accuracy': 0.9304623130912419}
# category       water
# accuracy    0.930462
# tn             23140
# fp              1404
# fn               419
# tp              1253
# dtype: object
# {'category': 'food', 'accuracy': 0.9101312175770522}
# category        food
# accuracy    0.910131
# tn             21707
# fp              1586
# fn               770
# tp              2153
# dtype: object
# {'category': 'shelter', 'accuracy': 0.9116951480012206}
# category     shelter
# accuracy    0.911695
# tn             22353
# fp              1549
# fn               766
# tp              1548
# dtype: object
# {'category': 'clothing', 'accuracy': 0.9795544705523345}
# category    clothing
# accuracy    0.979554
# tn             25419
# fp               392
# fn               144
# tp               261
# dtype: object
# {'category': 'money', 'accuracy': 0.9663945682026244}
# category       money
# accuracy    0.966395
# tn             24977
# fp               635
# fn               246
# tp               358
# dtype: object
# {'category': 'missing_people', 'accuracy': 0.9862297833384193}
# category    missing_people
# accuracy           0.98623
# tn                   25753
# fp                     165
# fn                     196
# tp                     102
# dtype: object
# {'category': 'refugees', 'accuracy': 0.9097116264876411}
# category    refugees
# accuracy    0.909712
# tn             23307
# fp              2034
# fn               333
# tp               542
# dtype: object
# {'category': 'death', 'accuracy': 0.9218416234360696}
# category       death
# accuracy    0.921842
# tn             23436
# fp              1586
# fn               463
# tp               731
# dtype: object
# {'category': 'other_aid', 'accuracy': 0.816486115349405}
# category    other_aid
# accuracy     0.816486
# tn              19371
# fp               3399
# fn               1412
# tp               2034
# dtype: object
# {'category': 'infrastructure_related', 'accuracy': 0.8014189807750992}
# category    infrastructure_related
# accuracy                  0.801419
# tn                           19953
# fp                            4558
# fn                             648
# tp                            1057
# dtype: object
# {'category': 'transport', 'accuracy': 0.8537152883735124}
# category    transport
# accuracy     0.853715
# tn              21632
# fp               3383
# fn                452
# tp                749
# dtype: object
# {'category': 'buildings', 'accuracy': 0.9204684162343607}
# category    buildings
# accuracy     0.920468
# tn              23275
# fp               1608
# fn                477
# tp                856
# dtype: object
# {'category': 'electricity', 'accuracy': 0.9690646933170582}
# category    electricity
# accuracy       0.969065
# tn                25086
# fp                  598
# fn                  213
# tp                  319
# dtype: object
# {'category': 'tools', 'accuracy': 0.9948123283490998}
# category       tools
# accuracy    0.994812
# tn             26029
# fp                28
# fn               108
# tp                51
# dtype: object
# {'category': 'hospitals', 'accuracy': 0.9860772047604517}
# category    hospitals
# accuracy     0.986077
# tn              25704
# fp                229
# fn                136
# tp                147
# dtype: object
# {'category': 'shops', 'accuracy': 0.9967958498626793}
# category       shops
# accuracy    0.996796
# tn             26093
# fp                 3
# fn                81
# tp                39
# dtype: object
# {'category': 'aid_centers', 'accuracy': 0.9845895636252671}
# category    aid_centers
# accuracy        0.98459
# tn                25681
# fp                  226
# fn                  178
# tp                  131
# dtype: object
# {'category': 'other_infrastructure', 'accuracy': 0.790509612450412}
# category    other_infrastructure
# accuracy                 0.79051
# tn                         19957
# fp                          5108
# fn                           384
# tp                           767
# dtype: object
# {'category': 'weather_related', 'accuracy': 0.8216737870003051}
# category    weather_related
# accuracy           0.821674
# tn                    16329
# fp                     2590
# fn                     2085
# tp                     5212
# dtype: object
# {'category': 'floods', 'accuracy': 0.8432636557827281}
# category      floods
# accuracy    0.843264
# tn             20665
# fp              3396
# fn               713
# tp              1442
# dtype: object
# {'category': 'storm', 'accuracy': 0.8935382972230699}
# category       storm
# accuracy    0.893538
# tn             21680
# fp              2093
# fn               698
# tp              1745
# dtype: object
# {'category': 'fire', 'accuracy': 0.985466890448581}
# category        fire
# accuracy    0.985467
# tn             25705
# fp               229
# fn               152
# tp               130
# dtype: object
# {'category': 'earthquake', 'accuracy': 0.9386634116570034}
# category    earthquake
# accuracy      0.938663
# tn               22838
# fp                 923
# fn                 685
# tp                1770
# dtype: object
# {'category': 'cold', 'accuracy': 0.9508696978944157}
# category       cold
# accuracy    0.95087
# tn            24602
# fp             1084
# fn              204
# tp              326
# dtype: object
# {'category': 'other_weather', 'accuracy': 0.818660360085444}
# category    other_weather
# accuracy          0.81866
# tn                  20586
# fp                   4254
# fn                    500
# tp                    876
# dtype: object
# {'category': 'direct_report', 'accuracy': 0.8319728410131217}
# category    direct_report
# accuracy         0.831973
# tn                  18396
# fp                   2745
# fn                   1660
# tp                   3415
# dtype: object
